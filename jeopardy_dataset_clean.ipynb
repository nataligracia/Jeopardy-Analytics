# %% [markdown]
# # Jeopardy Dataset Cleaning and Preparation

# %%
import pandas as pd
import pathlib
import numpy as np
import json

# %% [markdown]
# ## Add in a combined column of Questions & Answers with their stopwords removed for Jeopardy dataset that captures 500+ sample data from the raw dataset. This will be the base data of the our machine learning process.

# %%
import os
# Find the latest version of spark 2.0  from http://www-us.apache.org/dist/spark/ and enter as the spark version
# For example:
spark_version = 'spark-2.4.8'
# spark_version = 'spark-2.<enter version>'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://www-us.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark
# Set Environment Variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [450 kB]
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,770 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,184 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [480 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,414 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [33.6 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,616 kB]
# Get:23 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [906 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,184 kB]
# Get:25 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [40.9 kB]
# Fetched 12.4 MB in 4s (2,964 kB/s)
# Reading package lists... Done

# %%
# Start Spark session
from pyspark.sql import SparkSession
# spark = SparkSession.builder.appName("StopWords").getOrCreate()
spark = SparkSession.builder.appName("NLPTokens").getOrCreate()

# %%
# Read in the CSV to create data frame
raw_df = spark.read.csv("jeopardy-category-cleanup - cat_validated.csv", sep=",", header=True)

# %%
from pyspark.ml.feature import Tokenizer

# %%
# Tokenize DataFrame
tokenizer = Tokenizer(inputCol="combined", outputCol="words")

# %%
# Transform and show DataFrame
tokenized = tokenizer.transform(raw_df)
tokenized.show(truncate=False)
# Out:
# +-----------+----------+---------+-------------------------------+-----+--------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |show_number|air_date  |round    |category_title                 |value|data_q                                                                                                                    |data_a                                    |classes      |combined                                                                                                                                                            |words                                                                                                                                                                                             |
# +-----------+----------+---------+-------------------------------+-----+--------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |4680       |12/31/2004|Jeopardy!|HISTORY                        |$200 |For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory                          |Copernicus                                |people       |HISTORY For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory Copernicus                                                 |[history, for, the, last, 8, years, of, his, life,, galileo, was, under, house, arrest, for, espousing, this, man's, theory, copernicus]                                                          |
# |4680       |12/31/2004|Jeopardy!|ESPN's TOP 10 ALL-TIME ATHLETES|$200 |No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves               |Jim Thorpe                                |people       |ESPN's TOP 10 ALL-TIME ATHLETES No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves Jim Thorpe              |[espn's, top, 10, all-time, athletes, no., 2:, 1912, olympian;, football, star, at, carlisle, indian, school;, 6, mlb, seasons, with, the, reds,, giants, &, braves, jim, thorpe]                 |
# |4680       |12/31/2004|Jeopardy!|EVERYBODY TALKS ABOUT IT...    |$200 |The city of Yuma in this state has a record average of 4,055 hours of sunshine each year                                  |Arizona                                   |geography    |EVERYBODY TALKS ABOUT IT... The city of Yuma in this state has a record average of 4,055 hours of sunshine each year Arizona                                        |[everybody, talks, about, it..., the, city, of, yuma, in, this, state, has, a, record, average, of, 4,055, hours, of, sunshine, each, year, arizona]                                              |
# |4680       |12/31/2004|Jeopardy!|THE COMPANY LINE               |$200 |"In 1963, live on ""The Art Linkletter Show""                                                                             | this company served its billionth burger"|McDonald's   |organizations                                                                                                                                                       |[organizations]                                                                                                                                                                                   |
# |4680       |12/31/2004|Jeopardy!|EPITAPHS & TRIBUTES            |$200 |Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States                  |John Adams                                |people       |EPITAPHS & TRIBUTES Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States John Adams                             |[epitaphs, &, tributes, signer, of, the, dec., of, indep.,, framer, of, the, constitution, of, mass.,, second, president, of, the, united, states, john, adams]                                   |
# |4680       |12/31/2004|Jeopardy!|3-LETTER WORDS                 |$200 |In the title of an Aesop fable, this insect shared billing with a grasshopper                                             |the ant                                   |literature   |3-LETTER WORDS In the title of an Aesop fable, this insect shared billing with a grasshopper the ant                                                                |[3-letter, words, in, the, title, of, an, aesop, fable,, this, insect, shared, billing, with, a, grasshopper, the, ant]                                                                           |
# |4680       |12/31/2004|Jeopardy!|HISTORY                        |$400 |Built in 312 B.C. to link Rome & the South of Italy, it's still in use today                                              |the Appian Way                            |geography    |HISTORY Built in 312 B.C. to link Rome & the South of Italy, it's still in use today the Appian Way                                                                 |[history, built, in, 312, b.c., to, link, rome, &, the, south, of, italy,, it's, still, in, use, today, the, appian, way]                                                                         |
# |4680       |12/31/2004|Jeopardy!|ESPN's TOP 10 ALL-TIME ATHLETES|$400 |No. 8: 30 steals for the Birmingham Barons; 2,306 steals for the Bulls                                                    |Michael Jordan                            |people       |ESPN's TOP 10 ALL-TIME ATHLETES No. 8: 30 steals for the Birmingham Barons; 2,306 steals for the Bulls Michael Jordan                                               |[espn's, top, 10, all-time, athletes, no., 8:, 30, steals, for, the, birmingham, barons;, 2,306, steals, for, the, bulls, michael, jordan]                                                        |
# |4680       |12/31/2004|Jeopardy!|EVERYBODY TALKS ABOUT IT...    |$400 |In the winter of 1971-72, a record 1,122 inches of snow fell at Rainier Paradise Ranger Station in this state             |Washington                                |geography    |EVERYBODY TALKS ABOUT IT... In the winter of 1971-72, a record 1,122 inches of snow fell at Rainier Paradise Ranger Station in this state Washington                |[everybody, talks, about, it..., in, the, winter, of, 1971-72,, a, record, 1,122, inches, of, snow, fell, at, rainier, paradise, ranger, station, in, this, state, washington]                    |
# |4680       |12/31/2004|Jeopardy!|THE COMPANY LINE               |$400 |This housewares store was named for the packaging its merchandise came in & was first displayed on                        |Crate & Barrel                            |organizations|THE COMPANY LINE This housewares store was named for the packaging its merchandise came in & was first displayed on Crate & Barrel                                  |[the, company, line, this, housewares, store, was, named, for, the, packaging, its, merchandise, came, in, &, was, first, displayed, on, crate, &, barrel]                                        |
# |4680       |12/31/2004|Jeopardy!|EPITAPHS & TRIBUTES            |$400 |"""And away we go"""                                                                                                      |Jackie Gleason                            |people       |"EPITAPHS & TRIBUTES ""And away we go"" Jackie Gleason"                                                                                                             |["epitaphs, &, tributes, ""and, away, we, go"", jackie, gleason"]                                                                                                                                 |
# |4680       |12/31/2004|Jeopardy!|3-LETTER WORDS                 |$400 |Cows regurgitate this from the first stomach to the mouth & chew it again                                                 |the cud                                   |nature       |3-LETTER WORDS Cows regurgitate this from the first stomach to the mouth & chew it again the cud                                                                    |[3-letter, words, cows, regurgitate, this, from, the, first, stomach, to, the, mouth, &, chew, it, again, the, cud]                                                                               |
# |4680       |12/31/2004|Jeopardy!|HISTORY                        |$600 |In 1000 Rajaraja I of the Cholas battled to take this Indian Ocean island now known for its tea                           |Ceylon (or Sri Lanka)                     |geography    |HISTORY In 1000 Rajaraja I of the Cholas battled to take this Indian Ocean island now known for its tea Ceylon (or Sri Lanka)                                       |[history, in, 1000, rajaraja, i, of, the, cholas, battled, to, take, this, indian, ocean, island, now, known, for, its, tea, ceylon, (or, sri, lanka)]                                            |
# |4680       |12/31/2004|Jeopardy!|ESPN's TOP 10 ALL-TIME ATHLETES|$600 |"No. 1: Lettered in hoops, football & lacrosse at Syracuse & if you think he couldn't act, ask his 11 ""unclean"" buddies"|Jim Brown                                 |people       |"ESPN's TOP 10 ALL-TIME ATHLETES No. 1: Lettered in hoops, football & lacrosse at Syracuse & if you think he couldn't act, ask his 11 ""unclean"" buddies Jim Brown"|["espn's, top, 10, all-time, athletes, no., 1:, lettered, in, hoops,, football, &, lacrosse, at, syracuse, &, if, you, think, he, couldn't, act,, ask, his, 11, ""unclean"", buddies, jim, brown"]|
# |4680       |12/31/2004|Jeopardy!|EVERYBODY TALKS ABOUT IT...    |$600 |On June 28, 1994 the nat'l weather service began issuing this index that rates the intensity of the sun's radiation       |the UV index                              |science      |EVERYBODY TALKS ABOUT IT... On June 28, 1994 the nat'l weather service began issuing this index that rates the intensity of the sun's radiation the UV index        |[everybody, talks, about, it..., on, june, 28,, 1994, the, nat'l, weather, service, began, issuing, this, index, that, rates, the, intensity, of, the, sun's, radiation, the, uv, index]          |
# |4680       |12/31/2004|Jeopardy!|THE COMPANY LINE               |$600 |This company's Accutron watch, introduced in 1960, had a guarantee of accuracy to within one minute a month               |Bulova                                    |organizations|THE COMPANY LINE This company's Accutron watch, introduced in 1960, had a guarantee of accuracy to within one minute a month Bulova                                 |[the, company, line, this, company's, accutron, watch,, introduced, in, 1960,, had, a, guarantee, of, accuracy, to, within, one, minute, a, month, bulova]                                        |
# |4680       |12/31/2004|Jeopardy!|EPITAPHS & TRIBUTES            |$600 |"Outlaw: ""Murdered by a traitor and a coward whose name is not worthy to appear here"""                                  |Jesse James                               |people       |"EPITAPHS & TRIBUTES Outlaw: ""Murdered by a traitor and a coward whose name is not worthy to appear here"" Jesse James"                                            |["epitaphs, &, tributes, outlaw:, ""murdered, by, a, traitor, and, a, coward, whose, name, is, not, worthy, to, appear, here"", jesse, james"]                                                    |
# |4680       |12/31/2004|Jeopardy!|3-LETTER WORDS                 |$600 |A small demon, or a mischievous child (who might be a little demon!)                                                      |imp                                       |language     |3-LETTER WORDS A small demon, or a mischievous child (who might be a little demon!) imp                                                                             |[3-letter, words, a, small, demon,, or, a, mischievous, child, (who, might, be, a, little, demon!), imp]                                                                                          |
# |4680       |12/31/2004|Jeopardy!|HISTORY                        |$800 |Karl led the first of these Marxist organizational efforts; the second one began in 1889                                  |the International                         |history      |HISTORY Karl led the first of these Marxist organizational efforts; the second one began in 1889 the International                                                  |[history, karl, led, the, first, of, these, marxist, organizational, efforts;, the, second, one, began, in, 1889, the, international]                                                             |
# |4680       |12/31/2004|Jeopardy!|ESPN's TOP 10 ALL-TIME ATHLETES|$800 |"No. 10: FB/LB for Columbia U. in the 1920s; MVP for the Yankees in '27 & '36; ""Gibraltar in Cleats"""                   |(Lou) Gehrig                              |people       |"ESPN's TOP 10 ALL-TIME ATHLETES No. 10: FB/LB for Columbia U. in the 1920s; MVP for the Yankees in '27 & '36; ""Gibraltar in Cleats"" (Lou) Gehrig"                |["espn's, top, 10, all-time, athletes, no., 10:, fb/lb, for, columbia, u., in, the, 1920s;, mvp, for, the, yankees, in, '27, &, '36;, ""gibraltar, in, cleats"", (lou), gehrig"]                  |
# +-----------+----------+---------+-------------------------------+-----+--------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
# import stopwords library
from pyspark.ml.feature import StopWordsRemover

# %%
# Instantiate Remover
remover = StopWordsRemover(inputCol="words", outputCol="filtered")

# %%
# Transform and show data
filtered_df = remover.transform(tokenized)
filtered_df.show(truncate=False)
# Out:
# +-----------+----------+---------+-------------------------------+-----+--------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |show_number|air_date  |round    |category_title                 |value|data_q                                                                                                                    |data_a                                    |classes      |combined                                                                                                                                                            |words                                                                                                                                                                                             |filtered                                                                                                                                                          |
# +-----------+----------+---------+-------------------------------+-----+--------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |4680       |12/31/2004|Jeopardy!|HISTORY                        |$200 |For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory                          |Copernicus                                |people       |HISTORY For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory Copernicus                                                 |[history, for, the, last, 8, years, of, his, life,, galileo, was, under, house, arrest, for, espousing, this, man's, theory, copernicus]                                                          |[history, last, 8, years, life,, galileo, house, arrest, espousing, man's, theory, copernicus]                                                                    |
# |4680       |12/31/2004|Jeopardy!|ESPN's TOP 10 ALL-TIME ATHLETES|$200 |No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves               |Jim Thorpe                                |people       |ESPN's TOP 10 ALL-TIME ATHLETES No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves Jim Thorpe              |[espn's, top, 10, all-time, athletes, no., 2:, 1912, olympian;, football, star, at, carlisle, indian, school;, 6, mlb, seasons, with, the, reds,, giants, &, braves, jim, thorpe]                 |[espn's, top, 10, all-time, athletes, no., 2:, 1912, olympian;, football, star, carlisle, indian, school;, 6, mlb, seasons, reds,, giants, &, braves, jim, thorpe]|
# |4680       |12/31/2004|Jeopardy!|EVERYBODY TALKS ABOUT IT...    |$200 |The city of Yuma in this state has a record average of 4,055 hours of sunshine each year                                  |Arizona                                   |geography    |EVERYBODY TALKS ABOUT IT... The city of Yuma in this state has a record average of 4,055 hours of sunshine each year Arizona                                        |[everybody, talks, about, it..., the, city, of, yuma, in, this, state, has, a, record, average, of, 4,055, hours, of, sunshine, each, year, arizona]                                              |[everybody, talks, it..., city, yuma, state, record, average, 4,055, hours, sunshine, year, arizona]                                                              |
# |4680       |12/31/2004|Jeopardy!|THE COMPANY LINE               |$200 |"In 1963, live on ""The Art Linkletter Show""                                                                             | this company served its billionth burger"|McDonald's   |organizations                                                                                                                                                       |[organizations]                                                                                                                                                                                   |[organizations]                                                                                                                                                   |
# |4680       |12/31/2004|Jeopardy!|EPITAPHS & TRIBUTES            |$200 |Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States                  |John Adams                                |people       |EPITAPHS & TRIBUTES Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States John Adams                             |[epitaphs, &, tributes, signer, of, the, dec., of, indep.,, framer, of, the, constitution, of, mass.,, second, president, of, the, united, states, john, adams]                                   |[epitaphs, &, tributes, signer, dec., indep.,, framer, constitution, mass.,, second, president, united, states, john, adams]                                      |
# |4680       |12/31/2004|Jeopardy!|3-LETTER WORDS                 |$200 |In the title of an Aesop fable, this insect shared billing with a grasshopper                                             |the ant                                   |literature   |3-LETTER WORDS In the title of an Aesop fable, this insect shared billing with a grasshopper the ant                                                                |[3-letter, words, in, the, title, of, an, aesop, fable,, this, insect, shared, billing, with, a, grasshopper, the, ant]                                                                           |[3-letter, words, title, aesop, fable,, insect, shared, billing, grasshopper, ant]                                                                                |
# |4680       |12/31/2004|Jeopardy!|HISTORY                        |$400 |Built in 312 B.C. to link Rome & the South of Italy, it's still in use today                                              |the Appian Way                            |geography    |HISTORY Built in 312 B.C. to link Rome & the South of Italy, it's still in use today the Appian Way                                                                 |[history, built, in, 312, b.c., to, link, rome, &, the, south, of, italy,, it's, still, in, use, today, the, appian, way]                                                                         |[history, built, 312, b.c., link, rome, &, south, italy,, still, use, today, appian, way]                                                                         |
# |4680       |12/31/2004|Jeopardy!|ESPN's TOP 10 ALL-TIME ATHLETES|$400 |No. 8: 30 steals for the Birmingham Barons; 2,306 steals for the Bulls                                                    |Michael Jordan                            |people       |ESPN's TOP 10 ALL-TIME ATHLETES No. 8: 30 steals for the Birmingham Barons; 2,306 steals for the Bulls Michael Jordan                                               |[espn's, top, 10, all-time, athletes, no., 8:, 30, steals, for, the, birmingham, barons;, 2,306, steals, for, the, bulls, michael, jordan]                                                        |[espn's, top, 10, all-time, athletes, no., 8:, 30, steals, birmingham, barons;, 2,306, steals, bulls, michael, jordan]                                            |
# |4680       |12/31/2004|Jeopardy!|EVERYBODY TALKS ABOUT IT...    |$400 |In the winter of 1971-72, a record 1,122 inches of snow fell at Rainier Paradise Ranger Station in this state             |Washington                                |geography    |EVERYBODY TALKS ABOUT IT... In the winter of 1971-72, a record 1,122 inches of snow fell at Rainier Paradise Ranger Station in this state Washington                |[everybody, talks, about, it..., in, the, winter, of, 1971-72,, a, record, 1,122, inches, of, snow, fell, at, rainier, paradise, ranger, station, in, this, state, washington]                    |[everybody, talks, it..., winter, 1971-72,, record, 1,122, inches, snow, fell, rainier, paradise, ranger, station, state, washington]                             |
# |4680       |12/31/2004|Jeopardy!|THE COMPANY LINE               |$400 |This housewares store was named for the packaging its merchandise came in & was first displayed on                        |Crate & Barrel                            |organizations|THE COMPANY LINE This housewares store was named for the packaging its merchandise came in & was first displayed on Crate & Barrel                                  |[the, company, line, this, housewares, store, was, named, for, the, packaging, its, merchandise, came, in, &, was, first, displayed, on, crate, &, barrel]                                        |[company, line, housewares, store, named, packaging, merchandise, came, &, first, displayed, crate, &, barrel]                                                    |
# |4680       |12/31/2004|Jeopardy!|EPITAPHS & TRIBUTES            |$400 |"""And away we go"""                                                                                                      |Jackie Gleason                            |people       |"EPITAPHS & TRIBUTES ""And away we go"" Jackie Gleason"                                                                                                             |["epitaphs, &, tributes, ""and, away, we, go"", jackie, gleason"]                                                                                                                                 |["epitaphs, &, tributes, ""and, away, go"", jackie, gleason"]                                                                                                     |
# |4680       |12/31/2004|Jeopardy!|3-LETTER WORDS                 |$400 |Cows regurgitate this from the first stomach to the mouth & chew it again                                                 |the cud                                   |nature       |3-LETTER WORDS Cows regurgitate this from the first stomach to the mouth & chew it again the cud                                                                    |[3-letter, words, cows, regurgitate, this, from, the, first, stomach, to, the, mouth, &, chew, it, again, the, cud]                                                                               |[3-letter, words, cows, regurgitate, first, stomach, mouth, &, chew, cud]                                                                                         |
# |4680       |12/31/2004|Jeopardy!|HISTORY                        |$600 |In 1000 Rajaraja I of the Cholas battled to take this Indian Ocean island now known for its tea                           |Ceylon (or Sri Lanka)                     |geography    |HISTORY In 1000 Rajaraja I of the Cholas battled to take this Indian Ocean island now known for its tea Ceylon (or Sri Lanka)                                       |[history, in, 1000, rajaraja, i, of, the, cholas, battled, to, take, this, indian, ocean, island, now, known, for, its, tea, ceylon, (or, sri, lanka)]                                            |[history, 1000, rajaraja, cholas, battled, take, indian, ocean, island, known, tea, ceylon, (or, sri, lanka)]                                                     |
# |4680       |12/31/2004|Jeopardy!|ESPN's TOP 10 ALL-TIME ATHLETES|$600 |"No. 1: Lettered in hoops, football & lacrosse at Syracuse & if you think he couldn't act, ask his 11 ""unclean"" buddies"|Jim Brown                                 |people       |"ESPN's TOP 10 ALL-TIME ATHLETES No. 1: Lettered in hoops, football & lacrosse at Syracuse & if you think he couldn't act, ask his 11 ""unclean"" buddies Jim Brown"|["espn's, top, 10, all-time, athletes, no., 1:, lettered, in, hoops,, football, &, lacrosse, at, syracuse, &, if, you, think, he, couldn't, act,, ask, his, 11, ""unclean"", buddies, jim, brown"]|["espn's, top, 10, all-time, athletes, no., 1:, lettered, hoops,, football, &, lacrosse, syracuse, &, think, act,, ask, 11, ""unclean"", buddies, jim, brown"]    |
# |4680       |12/31/2004|Jeopardy!|EVERYBODY TALKS ABOUT IT...    |$600 |On June 28, 1994 the nat'l weather service began issuing this index that rates the intensity of the sun's radiation       |the UV index                              |science      |EVERYBODY TALKS ABOUT IT... On June 28, 1994 the nat'l weather service began issuing this index that rates the intensity of the sun's radiation the UV index        |[everybody, talks, about, it..., on, june, 28,, 1994, the, nat'l, weather, service, began, issuing, this, index, that, rates, the, intensity, of, the, sun's, radiation, the, uv, index]          |[everybody, talks, it..., june, 28,, 1994, nat'l, weather, service, began, issuing, index, rates, intensity, sun's, radiation, uv, index]                         |
# |4680       |12/31/2004|Jeopardy!|THE COMPANY LINE               |$600 |This company's Accutron watch, introduced in 1960, had a guarantee of accuracy to within one minute a month               |Bulova                                    |organizations|THE COMPANY LINE This company's Accutron watch, introduced in 1960, had a guarantee of accuracy to within one minute a month Bulova                                 |[the, company, line, this, company's, accutron, watch,, introduced, in, 1960,, had, a, guarantee, of, accuracy, to, within, one, minute, a, month, bulova]                                        |[company, line, company's, accutron, watch,, introduced, 1960,, guarantee, accuracy, within, one, minute, month, bulova]                                          |
# |4680       |12/31/2004|Jeopardy!|EPITAPHS & TRIBUTES            |$600 |"Outlaw: ""Murdered by a traitor and a coward whose name is not worthy to appear here"""                                  |Jesse James                               |people       |"EPITAPHS & TRIBUTES Outlaw: ""Murdered by a traitor and a coward whose name is not worthy to appear here"" Jesse James"                                            |["epitaphs, &, tributes, outlaw:, ""murdered, by, a, traitor, and, a, coward, whose, name, is, not, worthy, to, appear, here"", jesse, james"]                                                    |["epitaphs, &, tributes, outlaw:, ""murdered, traitor, coward, whose, name, worthy, appear, here"", jesse, james"]                                                |
# |4680       |12/31/2004|Jeopardy!|3-LETTER WORDS                 |$600 |A small demon, or a mischievous child (who might be a little demon!)                                                      |imp                                       |language     |3-LETTER WORDS A small demon, or a mischievous child (who might be a little demon!) imp                                                                             |[3-letter, words, a, small, demon,, or, a, mischievous, child, (who, might, be, a, little, demon!), imp]                                                                                          |[3-letter, words, small, demon,, mischievous, child, (who, might, little, demon!), imp]                                                                           |
# |4680       |12/31/2004|Jeopardy!|HISTORY                        |$800 |Karl led the first of these Marxist organizational efforts; the second one began in 1889                                  |the International                         |history      |HISTORY Karl led the first of these Marxist organizational efforts; the second one began in 1889 the International                                                  |[history, karl, led, the, first, of, these, marxist, organizational, efforts;, the, second, one, began, in, 1889, the, international]                                                             |[history, karl, led, first, marxist, organizational, efforts;, second, one, began, 1889, international]                                                           |
# |4680       |12/31/2004|Jeopardy!|ESPN's TOP 10 ALL-TIME ATHLETES|$800 |"No. 10: FB/LB for Columbia U. in the 1920s; MVP for the Yankees in '27 & '36; ""Gibraltar in Cleats"""                   |(Lou) Gehrig                              |people       |"ESPN's TOP 10 ALL-TIME ATHLETES No. 10: FB/LB for Columbia U. in the 1920s; MVP for the Yankees in '27 & '36; ""Gibraltar in Cleats"" (Lou) Gehrig"                |["espn's, top, 10, all-time, athletes, no., 10:, fb/lb, for, columbia, u., in, the, 1920s;, mvp, for, the, yankees, in, '27, &, '36;, ""gibraltar, in, cleats"", (lou), gehrig"]                  |["espn's, top, 10, all-time, athletes, no., 10:, fb/lb, columbia, u., 1920s;, mvp, yankees, '27, &, '36;, ""gibraltar, cleats"", (lou), gehrig"]                  |
# +-----------+----------+---------+-------------------------------+-----+--------------------------------------------------------------------------------------------------------------------------+------------------------------------------+-------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
# Convert the spark dataframe to pandas dataframe
jeopardy_df_raw = filtered_df.toPandas()
jeopardy_df_raw
# Out:
#     show_number  ...                                           filtered
# 0          4680  ...  [history, last, 8, years, life,, galileo, hous...
# 1          4680  ...  [espn's, top, 10, all-time, athletes, no., 2:,...
# 2          4680  ...  [everybody, talks, it..., city, yuma, state, r...
# 3          4680  ...                                    [organizations]
# 4          4680  ...  [epitaphs, &, tributes, signer, dec., indep.,,...
# ..          ...  ...                                                ...
# 531        5243  ...  [mexico, way, popular, resort, island, lies, n...
# 532        5243  ...  [take, pill, tranquilizer, sounds, like, villa...
# 533        5243  ...  [transportation, since, 1899, stalwart, animal...
# 534        5243  ...  ["an, e, ""to, replenish"", becomes, ""to, kno...
# 535        5243  ...  [british, theatre, richard, attenborough,, ori...
#
# [536 rows x 11 columns]

# %%
# Conver the 'filtered' column to a list
filtered_words = jeopardy_df_raw['filtered']
filtered_list = filtered_words.to_list()

# %%
# Use a for loop, join individual tokenized words to sentences

append_list = []
for x in filtered_list:

  append_list.append(' '.join(x))

# %%
append_list
# Out:
# ["history last 8 years life, galileo house arrest espousing man's theory copernicus",
#  "espn's top 10 all-time athletes no. 2: 1912 olympian; football star carlisle indian school; 6 mlb seasons reds, giants & braves jim thorpe",
#  'everybody talks it... city yuma state record average 4,055 hours sunshine year arizona',
#  'organizations',
#  'epitaphs & tributes signer dec. indep., framer constitution mass., second president united states john adams',
#  '3-letter words title aesop fable, insect shared billing grasshopper ant',
#  'history built 312 b.c. link rome & south italy, still use today appian way',
#  "espn's top 10 all-time athletes no. 8: 30 steals birmingham barons; 2,306 steals bulls michael jordan",
#  'everybody talks it... winter 1971-72, record 1,122 inches snow fell rainier paradise ranger station state washington',
#  'company line housewares store named packaging merchandise came & first displayed crate & barrel',
#  '"epitaphs & tributes ""and away go"" jackie gleason"',
#  '3-letter words cows regurgitate first stomach mouth & chew cud',
#  'history 1000 rajaraja cholas battled take indian ocean island known tea ceylon (or sri lanka)',
#  '"espn\'s top 10 all-time athletes no. 1: lettered hoops, football & lacrosse syracuse & think act, ask 11 ""unclean"" buddies jim brown"',
#  "everybody talks it... june 28, 1994 nat'l weather service began issuing index rates intensity sun's radiation uv index",
#  "company line company's accutron watch, introduced 1960, guarantee accuracy within one minute month bulova",
#  '"epitaphs & tributes outlaw: ""murdered traitor coward whose name worthy appear here"" jesse james"',
#  '3-letter words small demon, mischievous child (who might little demon!) imp',
#  'history karl led first marxist organizational efforts; second one began 1889 international',
#  '"espn\'s top 10 all-time athletes no. 10: fb/lb columbia u. 1920s; mvp yankees \'27 & \'36; ""gibraltar cleats"" (lou) gehrig"',
#  "everybody talks it... africa's lowest temperature 11 degrees zero 1935 ifrane, south fez country morocco",
#  'company line edward teller & man partnered 1898 sell high fashions women (paul) bonwit',
#  'people',
#  '3-letter words geologic time one these, shorter eon, divided periods & subdivided epochs era',
#  '"history asian political party founded 1885 ""indian national"" part name congress party"',
#  "espn's top 10 all-time athletes no. 5: center lead nba assists; track scholarship kansas u.; marathoner; volleyballer (wilt) chamberlain",
#  'company line kirschner brothers, & bill, named ski company & second-highest mountain k2',
#  '"epitaphs & tributes revolutionary war hero: ""his spirit vermont now"" ethan allen"',
#  "3-letter words single layer paper, perform one's craft diligently ply",
#  'literature',
#  'presidential states birth california nixon',
#  'airline travel place leave puppy take trip, carrier fits airplane seat kennel',
#  'old-time religion considered author pentateuch, hard believe, deuteronomy continues death moses',
#  'music',
#  '"""x""s & ""o""s around 100 a.d. tacitus wrote book art persuasive speaking declined since cicero oratory"',
#  'presidential states birth 1 2 born vermont coolidge (or chester arthur)',
#  "airline travel began pan & qantas late '70s, basically roped-off part economy cabin free drinks business class",
#  "old-time religion ali, married man's daughter fatima, considered shia muslims true successor muhammed",
#  '"musical trains 1954-1955 sun sessions, elvis climbed aboard train ""sixteen coaches long"" ""mystery train"""',
#  'consumables',
#  'literature',
#  "airline travel 2003 airline agreed buy klm, creating europe's largest airline air france",
#  'old-time religion philadelphia got start colony religious group william penn member quakers',
#  '"musical trains ""modern girl"" first hit billboard top 10 ""morning train (nine five)"" (sheena) easton"',
#  '"""x""s & ""o""s stiff silken fabric favored bridal gowns',
#  'literature',
#  'airline travel 2004 united launched new service features low fares & seats per plane ted',
#  "old-time religion mary i's accession 1553 ran geneva; returned 1559 & reformed church scotland (john) knox",
#  '"musical trains band\'s ""train vain"" hidden track original 1979 ""london calling"" album clash"',
#  '"""x""s & ""o""s cross-country skiing sometimes referred 2 letters',
#  'people',
#  'miscellaneous',
#  'old-time religion 1534 & buddy francis xavier founded society jesus (st. ignatius) loyola',
#  '"musical trains 1961 james brown announced ""all aboard"" train ""night train"""',
#  '"""x""s & ""o""s 1797 imbroglio began 3 french agents demanded huge bribe u.s. diplomats xyz affair"',
#  'solar system objects pass closer sun mercury named mythological figure icarus',
#  '"geography ""e"" largest kingdom united kingdom england"',
#  '"radio disney ""party u.s.a."" singer also plays young lady named hannah miley cyrus"',
#  "parts peach part peach downy fuzzy, fruit's called peach; smooth, nectarine skin",
#  'fruitful & multiply 4 x 12 48',
#  'bounce verb bouncing basketball sounds like slobbering dribbling',
#  'rhymes smart blood pumper heart',
#  'geography',
#  '"radio disney ""everybody else"" knows huggable toys precede ""on fire"" name radio disney top 30 band; you? care bears"',
#  'parts peach peaches 80% compound h2o',
#  'fruitful & multiply 7 x 7 x 2 98',
#  'bounce sound navigation& ranging full name device bounces radio waves underwater sonar',
#  'rhymes smart small, slender missile thrown board game dart',
#  '"geography ""e"" island south pacific named day discovery',
#  '"radio disney ""the songs \'under skin\' are...deeper \'let go\'"" said canadian radio disney\'s website avril lavigne"',
#  'parts peach 5-letter word hard interior peach stone',
#  'fruitful & multiply 3 x 4 x 5 x 6 360',
#  "bounce kid's game, bounce small rubber ball picking 6-pronged metal objects jacks",
#  'rhymes smart separating line hair role play part',
#  '"geography ""e"" parts arabian libyan deserts found african country egypt"',
#  'people',
#  'parts peach parts peach tree glossy green, pointed & lance shaped leaves',
#  'fruitful & multiply 5 x 10 x 15 750',
#  'bounce type bounce house, dance made famous michael jackson moonwalk',
#  'rhymes smart graphic representation information chart',
#  '"geography ""e"" family history wrote school might include entering u.s. island new york bay ellis island"',
#  '"radio disney lead singer ryan tedder band ""all right moves"" onerepublic"',
#  "parts peach parts peach tree grow nodes along shoots previous season's growth; usually pink blossoms",
#  'fruitful & multiply 2 x 1,035 2070',
#  '"let\'s bounce device whose name italian ""springboard"" perfected 1930s trampoline"',
#  'rhymes smart composer wolfgang mozart',
#  'science class 99.95% mass atom part nucleus',
#  "kids sports park view chula vista, california beat taipei 6-3 win organization's 2009 world series little league",
#  'facts hero several books 11 discovers wizard harry potter',
#  '"see & say say name <a href=""http://www.j-archive.com/media/2010-07-06_dj_26.jpg"" target=""_blank"">this</a> type mollusk see octopus"',
#  'news 7.0 magnitude earthquake caribbean country jan. 12, 2010 brought world outpouring aid haiti',
#  'dictionary 4-letter name pleated skirt worn men scotland kilt',
#  'science class plant process, carbon dioxide & water combine light energy create oxygen & glucose photosynthesis',
#  "kids sports perfect waves new zealand's piha beach site 2010 world junior championships surfing",
#  '"just facts city, seat clark county, nevada, called ""the entertainment capital world"" las vegas"',
#  '"see & say say <a href=""http://www.j-archive.com/media/2010-07-06_dj_27.jpg"" target=""_blank"">this</a> state admitted union 1859 oregon"',
#  'news car company news widespread recalls corollas & models toyota',
#  '"in dictionary adjective, mean proper; verb, ""to grade papers"" correct"',
#  'science class wedge adaptation simple machine called inclined plane',
#  'sports',
#  '"just facts <a href=""http://www.j-archive.com/media/2010-07-06_dj_14.jpg"" target=""_blank"">this dog breed seen here</a> loyal protective companion german shepherd"',
#  'nature',
#  'dracula',
#  'dictionary maize another word corn',
#  'science class 6 noble gases periodic table, lightest helium',
#  'kids sports 11-year-old ashlyn white won 2009 u.s. youth title martial art try throw opponent judo',
#  'facts 1751 penn provincial assembly placed order symbol freedom, philadelphia liberty bell',
#  '"see & say say name <a href=""http://www.j-archive.com/media/2010-07-06_dj_29.jpg"" target=""_blank"">these</a> big trees; color redwood"',
#  "news surprise, ted kennedy's old senate seat state went republican january 2010 election massachusetts",
#  '"in dictionary word someone walks comes latin ""foot"" pedestrian"',
#  "science class lava & igneous rock formed hot liquid rock material found earth's crust magma",
#  'kids sports sport under-17 world cup every 2 years; haris seferovic starred 2009 champion switzerland soccer',
#  'facts older son prince charles late princess diana prince william',
#  '"see & say say name <a href=""http://www.j-archive.com/media/2010-07-06_dj_30.jpg"" target=""_blank"">this</a> man see shaking hands premier china ronald reagan"',
#  '"news falcon heene, turned safe home, flying colorado, became known ""boy"" balloon boy"',
#  'dictionary kayak example this, word reads forwards & backwards palindrome',
#  'historic women born virginia around 1596 & died kent, england 1617 pocahontas',
#  '"royal female nicknames prime minister tony blair dubbed ""the people\'s princess"" princess diana"',
#  'entertainment',
#  "travel & tourism cinderella castle mystery tour highlight asian city's disneyland tokyo",
#  '"""i"" lads punk rock hitmaker heard numerous hits sides atlantic billy idol"',
#  ' says foreword novel"',
#  'backwords look smart vehicles returned london 1999 trams (smart)',
#  '"royal female nicknames ""the untamed heifer"" & ""the virgin queen"" elizabeth i"',
#  '"tv actors & roles barbra streisand knows played lt. col. bill ""raider"" kelly ""pensacola: wings gold"" james brolin"',
#  'travel & tourism home silk merchant jim thompson, disappeared 1967, tourist attraction thai city bangkok',
#  '"""i"" lads czar 17',
#  'people',
#  'backwords ed leaves pools water carpet comes sailing boat sloop (pools)',
#  '"royal female nicknames mark antony called ""the queen queens"" cleopatra"',
#  '"tv actors & roles (hi, wallace langham) played kirshner vh1\'s tv movie quartet sang ""daydream believer"" monkees"',
#  'travel & tourism stringing along: capital czech republic famous puppet theatres prague',
#  '"""i"" lads nudge',
#  '"forewords said husband frank o\'connor fuel kept spirited wrote ""the fountainhead"" ayn rand"',
#  'backwords naive think make bottled water popular evian (naive)',
#  '"royal female nicknames 19th century\'s ""widow windsor"" queen victoria"',
#  '"tv actors & roles teri hatcher looked ""shipshape"" one singing ""mermaids"" jumped board cruisin\' series 1985 love boat"',
#  'travel & tourism jomo kenyatta international airport serves world capital nairobi, kenya',
#  '"""i"" lads first & longest book bible\'s major prophets isaiah"',
#  '"forewords one edition calls darwin opus one ""the readable approachable"" revolutionary scientific works origin species"',
#  'backwords aye, lass, wed thee ere dried fields dew (wed)',
#  '"royal female nicknames ""the catholic"" 15th century spain queen isabella"',
#  'ferrell',
#  '"travel & tourism andrea palladio\'s 1554 book ""the antiquities of"" city standard guidebook 200 years rome"',
#  '"""i"" lads auto exec\'s autobiography one bestselling nonfiction works publishing history lee iacocca"',
#  'backwords know much policy, qualify wonk (know)',
#  'people history 15-year stay england, proprietor pennsylvania returned colony 1699 william penn',
#  'cinematic dictionary sfx standard abbreviation these, rustling trees cannon fire sound effects',
#  'ours! saint-pierre & miquelon france',
#  'british fashion designer vivienne westwood ran shop malcolm mclaren, launched johnny rotten band sex pistols',
#  "andy warhol thing lunch every day 20 years, andy warhol painted these, beginning 1962 campbell's soup cans",
#  '"theatre crossword clues ""m"" lerner & loewe\'s ""lusty month"" (3) may"',
#  'people history young man put savings small cleveland refinery 1862 & eventually oil monopoly john d. rockefeller',
#  'cinematic dictionary term flow film, maintained keeping details consistent throughout scene continuity',
#  'ours! montserrat great britain (united kingdom)',
#  'british fashion star designer john galliano born juan carlos galliano british possession tip spain gibraltar',
#  'andy warhol warhol went capitalist tendencies portrait man, seen mao tse-tung',
#  '"theatre crossword clues ""m"" patrick dennis\' ""auntie"" (4) mame"',
#  'people history first lady helen taft led fund-raising drive memorial 1912 marine disaster sinking titanic',
#  'entertainment',
#  'ours! cook islands new zealand',
#  '"british fashion katharine hamnett created \'80s t-shirt telling us ""choose"" life"',
#  '"andy warhol andy\'s ""15 minutes fame"" quote motto magazine interview"',
#  '"theatre crossword clues ""m"" ""becomes electra"" (8) mourning"',
#  "people history chiricahua apache popular attraction 1904 world's fair st. louis geronimo",
#  'cinematic dictionary inventors camera-stabilizing device won special 1977 oscar steadicam',
#  'ours! madeira islands portugal',
#  "andy warhol andy's loft east 47th street got nickname former use & andy's mass-production techniques factory",
#  '"theatre crossword clues ""m"" colchian jilted jason (5) medea"',
#  '"people history 1801 onetime vp compiled ""a manual parliamentary practice"" still used u.s. senate thomas jefferson"',
#  'entertainment',
#  'ours! northern mariana islands usa',
#  'andy warhol warhol became manager lou reed rock group 1965 & produced first album velvet underground',
#  '"theatre crossword clues ""m"" faust\'s fiendish foe (14) mephistopheles"',
#  "sports legends joe dimaggio's hitting streak gone one game 1941, company given $10,000 contract h.j. heinz (heinz 57 varieties)",
#  'general science white, glossy coating teeth hardest substance human body enamel',
#  "getting possessive bovine took rap disastrous fire october 8, 1871 mrs. o'leary's cow",
#  'flags world kingdom whose flag seen (union jack) great britain/england',
#  'architects minoru yamasaki reached new heights new york city complex world trade center',
#  '1994 films quentin tarantino directed film & also bit role jimmy toluca lake pulp fiction',
#  'eyes student, minor roman law pupil',
#  'general science time takes 50% atoms decay radioactive substance called half-life',
#  "getting possessive 14,140 feet, rocky mountain peak discovered 1806 one colorado's highest pike's peak",
#  'flags world seen flag nation (the home bollywood) india',
#  '"architects william pereira erected transamerica ""pyramid"" city san francisco"',
#  '1994 films mad bomber howard payne film, dennis hopper planted bomb l.a. area transit bus speed',
#  'eyes blow whip lash',
#  'general science compounds element added table salt, pure form quite poisonous iodine',
#  "getting possessive one creation slept, god took make eve adam's rib",
#  'flags world andy garcia native country whose flag seen cuba',
#  "architects charles bulfinch, contributed capitol washington, d.c., designed city's state house beacon hill boston",
#  '1994 films jean vander pyl, played wilma original cartoon series, played mrs. feldspar movie adaptation flintstones',
#  'eyes hollow area holds light bulb socket',
#  'red giants',
#  "getting possessive find triangular island 4 miles southeast coast massachusetts martha's vineyard",
#  'flags world 1990s, nation whose flag seen moved seat government different city germany',
#  'architects dallas-fort worth airport architect gyo obata helped design smithsonian museum air & space museum',
#  'entertainment',
#  'eyes flower seen (that fits category) iris',
#  'general science ph scale, ph 7 indicates type solution neutral',
#  "getting possessive exodus, thrown pharaoh moses' instruction aaron's rod (turned snake)",
#  '"flags world mediterranean country whose flag seen ""the word"" greece"',
#  'architects louis skidmore designed secret atomic site became tennessee town oak ridge',
#  '"1994 films film martin scorsese says tv audience wants ""to watch money"" quiz show"',
#  'eyes people say need make hollywood contacts',
#  'alaska 4 different species bears live alaska: kodiak, grizzly, black & polar bears',
#  "international sportsmen nike's stock fell basketball player announced retirement january 1999 michael jordan",
#  "drama queens euripides' play famed beauty, double goes troy helen",
#  'angels 1996 john travolta spread wings archangel michael',
#  'exile porfirio diaz seized power country 1876, ruled 35 years, fled 1911 & died exile mexico',
#  '"the ""i""s term fluid also mean ""to sign"" contract ink"',
#  'alaska tony knowles pulling $81,648 per annum job governor',
#  "international sportsmen ronaldo luiz nazario de lima began playing sport brazil's national team age 17 soccer",
#  'drama queens shaw play, caesar finds hiding sphinx cleopatra',
#  'harps',
#  'exile 1462 printer known movable type move mainz johannes gutenberg',
#  '"the ""i""s style 1877 painting seen impressionism"',
#  'alaska second-largest alaskan city named actor fairbanks',
#  "international sportsmen vladimir samsonov touted europe's hope china game ping-pong",
#  'drama queens 1952 play covered young life queen, like 1998 cate blanchett film elizabeth',
#  '"angels abba sang & curtis lee sang ""pretty little"" angel eyes"',
#  'exile exiled manslaughter, eric red forced leave country around 981 iceland',
#  'language',
#  ' ""north future"""',
#  'international sportsmen times london estimates chess player taking home $20 mil. year; check, mate! garry kasparov',
#  "drama queens 1935 & '36 helen hayes reigned 517 broadway performances queen reigned 63 years victoria",
#  'angels group whose feast day october 2, group founded 1979 curtis sliwa guardian angels',
#  'exile david ben-gurion went u.s. 1915 empire exiled zionists palestine ottoman empire',
#  'language',
#  'alaska mainland peninsula closest russia named man william seward',
#  'international sportsmen new zealand-born jonah lamu tops pitch sport rugby',
#  'people',
#  '"angels appropriate-sounding name, john dye plays angel ""touched angel"" angel death"',
#  "exile moshoeshoe ii exiled twice regaining southern african country's throne 1995 lesotho",
#  '"the ""i""s scientists believe universe undergoing expansion called',
#  "map europe bordering italy, austria, hungary & croatia, one world's newest independent countries slovenia",
#  'civil war first act sworn president confederacy send peace commission washington, d.c. jefferson davis',
#  'celebs sept. 14, 2005 gave birth sean preston federline britney spears',
#  'geography',
#  'emoticons ;-) ocular act sends signal winking',
#  "flag 'em alamo located city & depicted flag san antonio",
#  'seventeen.com',
#  'civil war tired eating mule jerky, vicksburg fell july 1863 6-week one military tactics siege',
#  '"celebs tv show ""everybody hates chris"" based childhood comic chris rock"',
#  'name? name shared great & terrible rulers russian variation john ivan',
#  '"emoticons :-$ emoticon tells ""put money"" mouth is"',
#  "flag 'em descriptive nickname u.s. flag coined francis scott key star-spangled banner",
#  '"""teen"" scene triskaidekaphobic',
#  "civil war robert e. lee saved capital capture june 1862 attack mcclellan's forces richmond",
#  'celebs auditioned & won part ron weasley rap wrote rupert grint',
#  '"what\'s name? feminine form rex latin ""queen"" regina"',
#  'emoticons :-* gene simmons might accept one pretty woman kiss',
#  "flag 'em 2 colors found 3 national flags u.s., mexico & canada red & white",
#  '"""teen"" scene holder liquid',
#  "civil war feb. 2005 reenactment staged 140th anniversary fort's reoccupation union troops fort sumter",
#  '"celebs 18th birthday party ""a cinderella story"" 300 guests & red velvet cake hilary duff"',
#  "name? welsh form margaret among usa's top 10 girls' names 1990s megan",
#  'emoticons #error! uncle sam',
#  '"flag \'em <a href=""http://www.j-archive.com/media/2006-02-06_j_29.jpg"" target=""_blank"">flag</a> u.s. possession almost flag cuba puerto rico"',
#  'language',
#  'people',
#  '"celebs ""you stand watching"" ""shine on"" singer ryan cabrera"',
#  '"what\'s name? previously attached theo- & isa-, became popular appearing ""david copperfield"" dora"',
#  'emoticons :-b.. means either hungry pig drooling',
#  "flag 'em first 50-star u.s. flag officially raised july 4 year 1960",
#  '"""teen"" scene number lines shakespeare\'s poem starts ""shall compare thee summer\'s day?"" 14"',
#  'current national capital ljubljana, bratislava, barcelona barcelona',
#  'u.s. winter olympians mike eruzione winthrop, mass. captain miraculous 1980 olympic team sport hockey',
#  'science sea level 70 degrees travels 1,129 feet per second; speeds 1 foot per sec. rising degree sound',
#  '"words writer ""i beheld wretch--the miserable monster created"" mary shelley"',
#  'organizations',
#  'greek name color comes greek word porphyra purple',
#  'current national capital istanbul, ottawa, amman istanbul',
#  ' 3rd utah"',
#  'science largest tree, general sherman california, type, also called sierra redwood sequoia',
#  'literature',
#  'mall skx stock symbol manufacturer sporty shoes skechers',
#  '"from greek bowl-shaped depression, impact meteorite, greek ""mixing bowl"" crater"',
#  'current national capital sofia, sarajevo, saigon saigon',
#  'u.s. winter olympians life ups & downs travis mayer, 2002 medalist event named little hills slopes moguls',
#  'strain',
#  'harper lee',
#  '"at mall ""urban"" store parent company anthropologie urban outfitters"',
#  'language',
#  'current national capital bucharest, bonn, bern bonn',
#  'u.s. winter olympians 2002 vonetta flowers & jill bakken won gold 2-woman version high-speed sport bobsled',
#  'science 6 elements known inert gases known aristocratic name noble gases',
#  ' friday me"""',
#  'organizations',
#  '"from greek (<a href=""http://www.j-archive.com/media/2006-02-06_dj_04.jpg"" target=""_blank"">jon clue crew paddles kayak.</a>) kayak example type reversible word greek ""running back again"" palindrome"',
#  'current national capital belize city, guatemala city, panama city belize city',
#  '"u.s. winter olympians ""bode"" work includes 2 alpine skiing silver medals 2002 bode miller"',
#  'caudal region',
#  '"words writer ""\'...why look\'st thou so?\'--\'with crossbow shot albatross\'"" samuel taylor coleridge"',
#  '"at mall name clothing store teens french ""airmail"" a?????ropostale"',
#  'greek outline contents course curriculum syllabus',
#  'famous ships december 27, 1831 departed plymouth, england map coastline south america hms beagle',
#  'old folks 30s goop.com lifestyles website oscar-winning actress; g & p represent initials gwyneth paltrow',
#  '"movies & tv march 19, 2009 said, ""i\'m excited honored introduce first guest... barack obama"" jay leno"',
#  'state college-ness baylor, stephen f. austin, rice texas',
#  'animal collective synonym dignity term group lions pride',
#  'rather skiing beginner, might hippity-hop smaller, gentler slope bunny hill',
#  'organizations',
#  'old folks 30s 2008 david gregory became moderator nbc sunday morning news show meet press',
#  '"movies & tv time magazine said 2003 pixar film ""the ultimate fish-out-of-water story"" finding nemo"',
#  'state college-ness antioch, bowling green, kent state ohio',
#  'animal collective like peas, whales & seals groups called pods',
#  'rather skiing something sprinkle shower, also term soft, dry, freshly fallen snow powder',
#  "parlez vous? duck, duck, l'oie; (l'oie course referring feathered friend) goose",
#  'old folks 30s linus torvalds father operating system used cell phones & supercomputers linux',
#  'harrison ford',
#  'state college-ness depaul, wheaton, northwestern illinois',
#  'animal collective crash group large horned mammals rhinoceroses',
#  'rather skiing california, premier spot skiing resort area shares name prehistoric elephant mammoth',
#  'language',
#  'old folks 30s district conservative rep. patrick mchenry state includes mooresville, home nascar north carolina',
#  '"movies & tv tim robbins played public tv newsman ""anchorman: legend of"" ron burgundy"',
#  "state college-ness wayne state, kalamazoo college, madonna university (it's franciscan catholic, material girl) michigan",
#  'animal collective pack dogs, place board kennel',
#  'rather skiing type race zigzag flags obstacles proper order slalom',
#  'language',
#  'old folks 30s elon musk making rockets & electric cars; co-founded & sold electronic payment system paypal',
#  "movies & tv frakkin' sad sci fi show series finale march 20, 2009 battlestar galactica",
#  'state college-ness grambling, mcneese state, southern louisiana',
#  'animal collective flock black birds called murder crows',
#  'rather skiing bumps mounds snow accumulate slope called these, like wealthy & powerful people moguls',
#  '"parlez vous? ""huitieme"" french ordinal number eighth"',
#  'american authors home orchard house model whre march family lived famous novel louisa may alcott',
#  'music',
#  'anatomy cord connects fetus placenta contains 2 arteries & 1 vein umbillical cord',
#  '"mathem-attack! che guevara probably knew political-sounding term root symbol seen <a href=""http://www.j-archive.com/media/2009-05-08_dj_26.jpg"" target=""_blank"">here</a> radical"',
#  'name decade world wide web gets first page 1990s',
#  '"word origins adjective meaning deceptive sneaky latin de via, meaning ""out way"" devious"',
#  '"american authors war 1812, ""rip van winkle"" author wrote biographies naval commanders washington irving"',
#  'music',
#  'anatomy human body 3 types these: skeletal, smooth & cardiac, combination skeletal & smooth muscles',
#  'mathem-attack! answer one automatically: property says = reflexive',
#  'name decade first controlled nuclear chain reaction 1940s',
#  '"word origins new york island\'s name may come algonquian word ""island"" manhattan"',
#  'american authors susan & benjamin cheever, children short story master, authors well john cheever',
#  'music',
#  'anatomy talus fits ends 2 bones forming ankle joint tibia & fibula',
#  'language',
#  '"name decade khruschev\'s ""secret speech"" denounces stalin 1950s"',
#  '"word origins compass direction may come proto-germanic ""to left rising sun"" north"',
#  '"american authors stood 5\'3"" & subject movies came 2005 & 2006 (truman) capote"',
#  'music',
#  'anatomy humans 33 vertebrae, 7 cervical, meaning part body neck',
#  'mathem-attack! symbol <i>i</i> used represent imaginary square root number -1',
#  'name decade george orwell, 34 years dead, hits bestseller list 1980s',
#  'language',
#  'philip roth',
#  'music',
#  'anatomy pons connects 2 hemispheres part brain regulates balance cerebellum',
#  'science',
#  'name decade man first reaches south pole 1910s',
#  '"word origins type ear implant help deaf, greek ""snail"" cochlear"',
#  'people',
#  'american explorers edward beale brought news 1848 discovery california east coast gold',
#  'measuring devices amount solution measured saccharometer sugar',
#  'mythology daedalus used substance fasten wings back wax',
#  '"television sunday night series subtitled ""the new adventures superman"" lois & clark"',
#  "annual events state's days '47 festival honors day brigham young reached salt lake valley 1847 utah",
#  'homophonic pairs complete donut center whole hole',
#  'american explorers stephen long & zebulon pike peaks named state, area said uninhabitable colorado',
#  'measuring devices energy measured pyrheliometer sun',
#  'mythology cadmus planted parts dragon raise troops teeth',
#  'nightmare elm street',
#  'annual events monroe, near snohomish state, site annual evergreen state fair washington',
#  "homophonic pairs restaurant, quartet's table request four",
#  'american explorers co-commanders 1st u.s. expedition explore mississippi west coast lewis & clark',
#  'measuring devices odometer measures distance covered vehicle & device measures far walked pedometer',
#  'mythology sister orestes, mourning became electra',
#  'television crime drama robert wagner & stefanie powers created sidney sheldon hart hart',
#  'annual events dog lovers look forward westminster kennel club dog show, held february city new york city',
#  'homophonic pairs contented performing kittens might paid way per purr',
#  'american explorers jedediah smith mountain man & explorer employed industry fur trading',
#  'measuring devices spirometer measures capacity organs lungs',
#  "mythology zeus' father, cronus, one group 12 titans",
#  'people',
#  'annual events pendleton roundup, annual rodeo, takes place pendleton northwestern state oregon',
#  "homophonic pairs squash pierced bull's horn gored gourd",
#  '"american explorers senator thomas hart benton\'s son-in-law ""pathfinder"" john c. fr?????mont"',
#  'measuring devices nilometer measures height water nile river',
#  'mythology leda laid 2 eggs: one helen & pollux it, containing clytemnestra & castor',
#  'entertainment',
#  'annual events tanglewood music festival summer highlight lenox new england state massachusetts',
#  'homophonic pairs remained sedate stayed staid',
#  'notable nonhumans nazi dictator sometimes dined alone blondi, alsatian adolf hitler',
#  'world facts isthmus connects north & south america isthmus panama',
#  '"art & artists painted ""irises"" & ""pink roses"" well ""sunflowers"" vincent van gogh"',
#  'business & industry 9,700 tax preparation offices worldwide h&r block',
#  'history historians refer golden age time pericles ruled city athens',
#  "poets feb. 12, 1959, 150th anniversary lincoln's birth, addressed joint session congress carl sandburg",
#  'notable nonhumans 1964 lifted beagles & ears white house lawn, provoking protest lyndon johnson',
#  'world facts humid city, rio de janeiro lies north tropic line tropic capricorn',
#  'art & artists drip artist born cody, wyoming 1912 jackson pollock',
#  'business & industry 1961 firm introduced selectric typewriter, used spherical typing element ibm',
#  'history 1814 treaty kiel, country gave norway sweden kept greenland & islands denmark',
#  '"poets 1842 & 1885, repeatedly revised ""idylls king"" alfred lord tennyson"',
#  'notable nonhumans colo first great apes born captivity, 1956 columbus zoo gorilla',
#  'world facts lowest river world, revered jews, christians & muslims alike river jordan',
#  'people',
#  '"business & industry 1934 plugged bulova ""lone eagle"" watches charles lindbergh"',
#  'history february 1904 country attacked russian fleet port arthur japan',
#  'poets much winter 1794-95, served acting supervisor dumfries, scotland robert burns',
#  "notable nonhumans 1945 famous scottie injured fight blaze, elliott roosevelt's mastiff fala",
#  "world facts discovered david livingstone, botswana's lake ngami lies northern part desert kalahari desert",
#  'auguste rodin',
#  'business & industry philip morris & cincinnati-based firm yearly ad expenditures exceeding $2 billion procter & gamble',
#  "history may 30, 1967 colonel ojukwu declared biafra's independence country, starting civil war nigeria",
#  '"poets ""i heard fly buzz"" may based chapter ""the house seven gables"" emily dickinson"',
#  'notable nonhumans favorite horse alexander great sometimes wore golden horns battle bucephalus',
#  'world facts area country whose capital called yangon largest mainland southeast asia myanmar (burma)',
#  '"art & artists see british sculptor\'s ""reclining mother child"" walker art center minneapolis henry moore"',
#  'business & industry 1811 german family began steel-making business constructing plant essen krupp',
#  'history midst korean war, south korean president elected second 4 terms syngman rhee',
#  '"poets wrote, ""i choose plain new hampshire farmer"" robert frost"',
#  '"british novels 1895 novel subtitled ""an invention"" time machine"',
#  'lost space making repairs intl. space station, scott parazynski lost needle-nose pair pliers',
#  "timeless tv september 2010 brought 45th edition comedian's telethon jerry lewis",
#  'language',
#  'people',
#  'money slang give $200, $1,000, five letter word meaning stately majestic grand',
#  'science',
#  'lost space years operation, soviet space station released 200 objects (mostly trash) space mir',
#  'timeless tv originally half hour, soap started 1963 & featured nurse jessie brewer general hospital',
#  'hit word seen doors right-handed batter hits ball left field pull',
#  'people',
#  'language',
#  ' sold 400',
#  '"lost space ed white, first u.s. spacewalker, lost one outside gemini 4; must\'ve looked like later ""moonwalker"" glove"',
#  "timeless tv 1948 douglas edwards became first anchor network's evening news cbs",
#  'hit aaron fechter invented carnival game hit mammal mallet whack-a-mole',
#  '"world book describes ""g"" man ""american poet... became known leader beat literary movement 1950s"" (allen) ginsberg"',
#  'money slang shell mollusk composed chiefly calcium carbonate clam',
#  'people',
#  "lost space piers sellers lost tool space spreading putty space shuttle named capt. cook's ship discovery",
#  "timeless tv shown saturday afternoons abc, sport's tour outdrew college football & moved espn 1997 pro bowling tour",
#  'hit everlast makes come speed heavy varieties punching bags',
#  'people',
#  'money slang get 5 guesses winglike appendage underwater portion hull fin',
#  '"lost space 1992 space shuttle astronauts delivered ashes ""star trek"" creator final frontier gene roddenberry"',
#  '"timeless tv 2010\'s ""when love enough"" 240th presentation series greeting card company hallmark hall fame"',
#  'hit casinos, blackjack dealer must hit ace & 6, known type 17 soft',
#  '"world book describes ""g"" man ""one original provocative american architects working today"" (frank) gehry"',
#  'money slang speaking messrs. netanyahu britten, first name, pluralized benjamins',
#  'play heroines blanche dubois streetcar named desire',
#  'defenestration cinema giving devil due, fr. karras invites devil inside himself, exits second floor 1973 movie exorcist',
#  '"a massive ""m""etropolis 3.6 million: melbourne"',
#  'tainted gov 2010 illinois governor tried corruption charges, convicted 1 count blagojevich',
#  "medicine franklin d. roosevelt's blood pressure 300/190, suffered 1-word condition hypertension",
#  '4 consonants row vertical supported palms, one handstand',
#  "play heroines emily webb grover's corners town",
#  'defenestration cinema bruce willis movie, villain goes window nakatomi building, gun hand die hard',
#  '"a massive ""m""etropolis 11 million: luzon island manila"',
#  'tainted gov 2006 illinois governor busted racketeering; water there? george ryan',
#  'medicine 1905 german scientist alfred einhorn created first injectable local anesthetic used dentistry novocaine',
#  '4 consonants row caterpillar moves contraction & expansion inchworm',
#  '"defenestration cinema movie axel foley asks, ""where ...you get arresting thrown window?"" beverly hills cop"',
#  '"a massive ""m""etropolis 1.1 million: heart po river valley milan"',
#  'tainted gov 2010 revealed robert rizzo made $800,000 year city bell, calif., population 37,000 manager',
#  '"medicine micro-trach oxygen delivery system developed physician known ""maneuver"" (henry) heimlich"',
#  "4 consonants row loop found footwear, symbol success one's efforts bootstrap",
#  '"a massive ""m""etropolis 18 million: arabian sea mumbai"',
#  'tainted gov 2010 house committee charged veteran harlem congressman ethics violations (charlie) rangel',
#  'science',
#  '4 consonants row hard coal burns little flame anthracite',
#  'play heroines barbara undershaft major barbara',
#  'defenestration cinema coen brothers movie, charles durning jumps window board meeting hudsucker proxy',
#  '"a massive ""m""etropolis 3.2 million: 150 miles bogota medellin"',
#  "tainted gov elected senate 1930, refused resign louisiana's gov. '32, handpicked crony got gig huey long",
#  '"medicine name branch pediatrics deals newborn infants literally means ""newborn study"" neonatal"',
#  '4 consonants row important mechanism turning wind clock mainspring',
#  '"flags world use 1844 1905, flag representing union 2 countries nicknamed ""herring salad"" norway sweden"',
#  'people',
#  'beginning & end like door, broadway show 2 things open & close',
#  'state superlatives valley 282 feet sea level state lowest point western hemisphere california',
#  '3 little letters like banks, many grocery stores dispensing cash & taking deposits atms',
#  '"call voice squad voice mickey mouse ""steamboat willie"" walt disney"',
#  '"you\'re ""rest"" eastern european capital city 2.2 million bucharest"',
#  '"american authors 1884 moved red cloud, nebraska & later fictionalized town hanover ""o pioneers!"" willa cather"',
#  'beginning & end 2006 began july 1 strasbourg & ended july 23 paris tour de france',
#  'state superlatives 6,640 miles coast, state longest shoreline alaska',
#  '"3 little letters (<a href=""http://www.j-archive.com/media/2007-05-30_j_09.jpg"" target=""_blank"">cheryl clue crew reports catalina island conservancy.</a>) rampant use 3-letter insecticide lead hefty settlement restorating population catalina\'s <a href=""http://www.j-archive.com/media/2007-05-30_j_09a.jpg"" target=""_blank"">bald eagles</a> ddt"',
#  'ned flanders',
#  '"you\'re ""rest"" mountain\'s summit crest"',
#  '(harriet beecher) stowe',
#  '"beginning & end ""from"" idiom meaning start meal (or something else) end soup nuts"',
#  'state superlatives pumps one million barrels oil day, state texas',
#  '"3 little letters ""day day"" & ""all things considered"" among programs going 26 million listeners npr"',
#  'call voice squad voice daffy duck (for first 50 years) mel blanc',
#  '"you\'re ""rest"" braced framework carrying railroad chasm trestle"',
#  'american authors name laura bancroft, wrote twinkle & chubbins nature fairyland taking us oz l. frank baum',
#  '"beginning & end titles <a href=""http://www.j-archive.com/media/2007-05-30_j_17.jpg"" target=""_blank"">2 paintings</a> <a href=""http://www.j-archive.com/media/2007-05-30_j_17a.jpg"" target=""_blank"">seen here</a> represent beginning & end jesus\' life ""the nativity"" & ""the crucifixion"""',
#  'state superlatives considered healthiest state 2006, also home mayo clinic minnesota',
#  '3 little letters headquarters compound langley, virginia named former president george bush cia',
#  '"call voice squad voiced puss boots ""shrek 2"" antonio banderas"',
#  '"you\'re ""rest"" quickly! (to italian) presto"',
#  'people',
#  'takeoff & landing (or launch & arrival)',
#  "state superlatives boeing manufacturing plant everett world's largest building volume washington",
#  '3 little letters tv cable network, explosive bombs tnt',
#  'call voice squad provided voices beavis & butthead mike judge',
#  '"you\'re ""rest"" son agamemnon',
#  'early america 1718 texas town founded martin de alarcon & father olivares & named st. anthony padua san antonio',
#  '"best picture oscar-winners words 1980: ""regular folks"" ordinary people"',
#  'mexico way 1986 mexico scored first country host international sports competition twice world cup',
#  '"take pill going cruise? might pick pfizer product, ""original"" ""less drowsy"" formula dramamine"',
#  "transportation bestselling passenger car time company's corolla toyota",
#  'e hawaiian wreath becomes area sheltered wind lei & lee',
#  '"early america defending british soldiers trial 1770 event, john adams said, ""facts stubborn things"" boston massacre"',
#  '"best picture oscar-winners words 1932: ""magnificent inn"" grand hotel"',
#  'mexico way resort city 200 miles southwest mexico city famous cliff divers acapulco',
#  'take pill antabuse designed make feel really, really bad ingesting alcohol',
#  'transportation transport 19th century double date might barouche, one carriage',
#  '"an e ""landing"" area transformed serious throat infection strep & strip"',
#  'early america 1685 joined father pastorship old north church, post held death cotton mather',
#  '"best picture oscar-winners words 1976: ""a single colorado mountain"" rocky"',
#  'mexico way founded 1530s, capital jalisco state second-largest mexico guadalajara',
#  'take pill estramustine chemotherapy agent glandular cancer men prostate cancer',
#  'geography',
#  '"an e ""gentle"" becomes ""to blend"" mild & meld"',
#  'early america 1562, s.c., french protestants established colony named port royal huguenots',
#  '"best picture oscar-winners words 1954: ""dockside"" waterfront"',
#  'mexico way gritty 1961 tennessee williams play unfolds seedy mexican hotel night iguana',
#  "take pill pravastatin aims block body's ability make cholesterol",
#  'bus',
#  'language',
#  'people',
#  '"best picture oscar-winners words 1966: ""one bloke year-round"" man seasons"',
#  'mexico way popular resort island lies north cozumel coast state quintana roo cancun',
#  "take pill tranquilizer sounds like village introduced 1955 & became usa's bestselling drug miltown",
#  'transportation since 1899 stalwart animals used transport served mascots army corps cadets mules',
#  '"an e ""to replenish"" becomes ""to knock down"" fill & fell"',
#  'british theatre richard attenborough, original 1952 cast play, helped celebrate performance no. 20,000 2000 mousetrap']

# %%
# Make a copy of the dataframe
jeopardy_df = jeopardy_df_raw

# %%
# Drop the unnecessary columns in the dataframe, only keep the filtered_sentences
jeopardy_df = jeopardy_df.drop(['words', 'filtered'], axis=1)
jeopardy_df['filtered_sentence'] = append_list

# %%
jeopardy_df
# Out:
#     show_number  ...                                  filtered_sentence
# 0          4680  ...  history last 8 years life, galileo house arres...
# 1          4680  ...  espn's top 10 all-time athletes no. 2: 1912 ol...
# 2          4680  ...  everybody talks it... city yuma state record a...
# 3          4680  ...                                      organizations
# 4          4680  ...  epitaphs & tributes signer dec. indep., framer...
# ..          ...  ...                                                ...
# 531        5243  ...  mexico way popular resort island lies north co...
# 532        5243  ...  take pill tranquilizer sounds like village int...
# 533        5243  ...  transportation since 1899 stalwart animals use...
# 534        5243  ...  "an e ""to replenish"" becomes ""to knock down...
# 535        5243  ...  british theatre richard attenborough, original...
#
# [536 rows x 10 columns]

# %%
# Save the filttered sample dataset to a CSV
jeopardy_df.to_csv('filtered_smaller_sample.csv')

# %% [markdown]
# ## Next, prepare the JSON file for the raw Jeopardy dataset. This will serve as the base dataset for our web keyword searches.

# %%
# Read in the Jeopardy JSON file
with open('JEOPARDY_QUESTIONS1.json', 'r') as json_file:
    json_object = json.load(json_file)

# %%
# Prettified the JSON string
json_file = json.dumps(json_object, indent=1)

# %%
# Save the prettified string to a JSON file
jsonFile = open("jeopardy.json", "w")
jsonFile.write(json_file)
jsonFile.close()
